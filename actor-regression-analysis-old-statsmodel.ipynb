# %%
import pandas as pd
import statsmodels.api as sm
from patsy import dmatrices

actor_full = pd.read_pickle('actor_full.pickle')

print actor_full.shape

print actor_full.dtypes
# Out:
# (16416, 348)
# rank                                                                            object
# title                                                                           object
# studio                                                                          object
# adjusted_gross                                                                 float64
# unadjusted_gross                                                                 int64
# release                                                                 datetime64[ns]
# actor_id                                                                        object
# Canadian male voice actors                                                        bool
# 21st-century Australian actresses                                                 bool
# Canadian male television actors                                                   bool
# English people of Irish descent                                                   bool
# ...

# %%
# gross = actor_full.adjusted_gross

# actor_analyzable = actor_full.drop(['rank','title','studio','actor_id','adjusted_gross','unadjusted_gross'], axis=1)
# actor_analyzable.dtypes

# %%
actor_full.head()
# Out:
#         rank                   title studio  adjusted_gross  unadjusted_gross  \
# 50 Cent    1                     Spy    Fox       116867700         110825712
# 50 Cent    2                Southpaw  Wein.        55265500          52421953
# 50 Cent    3          Righteous Kill  Over.        48566600          40081410
# 50 Cent    4  Get Rich or Die Tryin'   Par.        42048300          30985352
# 50 Cent    5             Escape Plan   LG/S        26202200          25135965
#
#            release actor_id Canadian male voice actors  \
# 50 Cent 2015-06-05   50cent                      False
# 50 Cent 2015-07-24   50cent                      False
# 50 Cent 2008-09-12   50cent                      False
# 50 Cent 2005-11-09   50cent                      False
# 50 Cent 2013-10-18   50cent                      False
#
#         21st-century Australian actresses Canadian male television actors  \
# 50 Cent                             False                           False
# ...

# %%
actor_clean = actor_full.copy()
for col in actor_clean:
    if isinstance(actor_clean[col].dtype, bool) or isinstance(actor_clean[col].dtype, pd.Timedelta):
        print col, actor_clean[col].dtype
        actor_clean[col].astype(int)
    
actor_clean.dropna()

# actor_clean.head()
y, X = dmatrices('adjusted_gross ~ age_on_release + bday', data=actor_clean, return_type='dataframe')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-b91e12d6d508> in <module>()
#       8
#       9 # actor_clean.head()
# ---> 10 y, X = dmatrices('adjusted_gross ~ age_on_release + bday', data=actor_clean, return_type='dataframe')
#
# /home/ian/anaconda2/lib/python2.7/site-packages/patsy/highlevel.pyc in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     295     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     296     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 297                                       NA_action, return_type)
#     298     if lhs.shape[1] == 0:
#     299         raise PatsyError("model is missing required outcome variables")
#
# /home/ian/anaconda2/lib/python2.7/site-packages/patsy/highlevel.pyc in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
# ...

# %%
# mod = sm.OLS(gross, actor_analyzable)
mod = sm.OLS(y, X)
res = mod.fit()

res.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-f8bb72d09e2e> in <module>()
# ----> 1 mod = sm.OLS(gross, actor_analyzable)
#       2 res = mod.fit()
#       3
#       4 res.summary()
#
# /home/ian/anaconda2/lib/python2.7/site-packages/statsmodels/regression/linear_model.pyc in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     689                  **kwargs):
#     690         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 691                                   hasconst=hasconst, **kwargs)
#     692         if "weights" in self._init_keys:
#     693             self._init_keys.remove("weights")
#
# /home/ian/anaconda2/lib/python2.7/site-packages/statsmodels/regression/linear_model.pyc in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     584             weights = weights.squeeze()
# ...
